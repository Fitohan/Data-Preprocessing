# %% [markdown]
# 1. Import the dataset into your notebook, print out the first 10 rows, check the statistical and general information

# %%
import pandas as pd

hepatitisfile = pd.read_csv(r"C:\Users\FITOHAN\Downloads\hepatitis.csv",encoding="latin1")

hepatitisfile.head(10)
# Out:
#    age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0   30    male   False       False   False   False    False     False
# 1   50  female   False       False    True   False    False     False
# 2   78  female    True       False    True   False    False      True
# 3   31  female     NaN        True   False   False    False      True
# 4   34  female    True       False   False   False    False      True
# 5   34  female    True       False   False   False    False      True
# 6   51  female   False       False    True   False     True      True
# 7   23  female    True       False   False   False    False      True
# 8   39  female    True       False    True   False    False      True
# 9   30  female    True       False   False   False    False      True
#
#   liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# 0      False           False   False   False   False        1.0
# 1      False           False   False   False   False        0.9
# ...

# %% [markdown]
# 2. Check for the sum of the missing values and the percentage of missing values.

# %%
# Total of missing values
df = hepatitisfile.isnull().sum()
df
# Out:
# age                 0
# sex                 0
# steroid             1
# antivirals          0
# fatigue             1
# malaise             1
# anorexia            1
# liver_big          10
# liver_firm         11
# spleen_palpable     5
# spiders             5
# ascites             5
# varices             5
# bilirubin           6
# alk_phosphate      29
# sgot                4
# albumin            16
# protime            67
# histology           0
# class               0
# dtype: int64

# %%
#Percentage of missing value
newdf = (hepatitisfile.isnull().sum()/ len(hepatitisfile))*100 
newdf
# Out:
# age                 0.000000
# sex                 0.000000
# steroid             0.645161
# antivirals          0.000000
# fatigue             0.645161
# malaise             0.645161
# anorexia            0.645161
# liver_big           6.451613
# liver_firm          7.096774
# spleen_palpable     3.225806
# spiders             3.225806
# ascites             3.225806
# varices             3.225806
# bilirubin           3.870968
# alk_phosphate      18.709677
# sgot                2.580645
# albumin            10.322581
# protime            43.225806
# histology           0.000000
# class               0.000000
# dtype: float64

# %% [markdown]
# 3. Choose one option: Drop the columns with missing values or fill the columns with missing values. Give your reasons.

# %%
#Fill the columns with missing values
hepatitis_file=hepatitisfile.fillna(method="bfill")
hepatitis_file

#Reason:
#I filled the dataset because every rows and columns of a dataset is important inorder to avoids loss of data, 
#which can impact the integrity or the quality of the data.
# Out:
#      age     sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0     30    male    False       False    False    False     False      False
# 1     50  female    False       False     True    False     False      False
# 2     78  female     True       False     True    False     False       True
# 3     31  female     True        True    False    False     False       True
# 4     34  female     True       False    False    False     False       True
# ..   ...     ...      ...         ...      ...      ...       ...        ...
# 150   46  female     True       False     True     True      True       True
# 151   44  female     True       False     True    False     False       True
# 152   61  female    False       False     True     True     False      False
# 153   53    male    False       False     True    False     False       True
# 154   43  female     True       False     True    False     False       True
#
# ...

# %% [markdown]
# 4. Choose a column and rename it. Give your reasons for picking that column

# %%
#Renaming a column
hepatitis_file12=hepatitis_file.rename(columns={"spiders": "diarrhea"})
hepatitis_file12

#Reason:
#I picked spiders columns because it is not a unique fieldname,spider isnot part of the symptoms of hepatitis.
# Out:
#      age     sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0     30    male    False       False    False    False     False      False
# 1     50  female    False       False     True    False     False      False
# 2     78  female     True       False     True    False     False       True
# 3     31  female     True        True    False    False     False       True
# 4     34  female     True       False    False    False     False       True
# ..   ...     ...      ...         ...      ...      ...       ...        ...
# 150   46  female     True       False     True     True      True       True
# 151   44  female     True       False     True    False     False       True
# 152   61  female    False       False     True     True     False      False
# 153   53    male    False       False     True    False     False       True
# 154   43  female     True       False     True    False     False       True
#
# ...

# %% [markdown]
# 5. Check the number of missing values after cleaning and state the impact on data analysis.

# %%
# Total of missing values
impact=hepatitis_file.isnull().sum()
impact

#State the impact on data analysis
# It improves data quality and in doing so, increases overall productivity.
# It makes analyses run faster, correct and provides accurate information.
# Out:
# age                0
# sex                0
# steroid            0
# antivirals         0
# fatigue            0
# malaise            0
# anorexia           0
# liver_big          0
# liver_firm         0
# spleen_palpable    0
# spiders            0
# ascites            0
# varices            0
# bilirubin          0
# alk_phosphate      0
# sgot               0
# albumin            0
# protime            0
# histology          0
# class              0
# dtype: int64
